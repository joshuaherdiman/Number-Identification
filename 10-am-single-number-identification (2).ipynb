# %%
from fastai.vision.all import *

# %%
path = "/kaggle/input/mnistasjpg/trainingSample/trainingSample"
mnist_images = get_image_files(path)
print(len(number_files))
# Out:
# 600

# %%
img = PILImage.create(number_files[0])
img.show

img = PILImage.create(number_files[1])
img.show
# Out:
# <bound method PILBase.show of PILImage mode=RGB size=28x28>

# %%
def number_label(file_name):
    if file_name[-1] == "/":
        return file_name[-2:-1]
    return file_name[-1]

print(number_label("/kaggle/input/numerical-images/numbers/mnist_png/Hnd/Sample0"))
print(number_label("/kaggle/input/numerical-images/numbers/mnist_png/Hnd/Sample0/"))
# Out:
# 0
# 0
